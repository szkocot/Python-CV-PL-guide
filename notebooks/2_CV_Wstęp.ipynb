# %% [markdown]
# # Wstęp do wizji komputerowej w pythonie

# %%
from PIL import Image

# %% [markdown]
# ## Wczytanie obrazu

# %%
img = Image.open('../obrazy_testowe/lena_512x512.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x1B1A6ECB390>
